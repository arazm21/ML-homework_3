# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment2/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# Run this notebook once you have completed all the other notebooks: `FullyConnectedNets.ipynb`, `BatchNormalization.ipynb`, `Dropout.ipynb`, `ConvolutionalNetworks.ipynb`, `PyTorch.ipynb`).
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a2_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `a2_inline_submission.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a2_code_submission.zip and the a2_inline_submission.pdf to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
# Out:
# /content/drive/My Drive/cs231n/assignments/assignment2
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# texlive-fonts-recommended is already the newest version (2021.20220204-1).
# texlive-latex-extra is already the newest version (2021.20220204-1).
# texlive-plain-generic is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# ...
# ### Zipping file ###
# ### Creating PDFs ###
# Created PDF FullyConnectedNets.ipynb.
# Created PDF BatchNormalization.ipynb.
# Created PDF Dropout.ipynb.
# [NbConvertApp] CRITICAL | xelatex failed: ['xelatex', 'notebook.tex', '-quiet']
# ...

# %%
# !jupyter nbconvert --to html FullyConnectedNets.ipynb
# Out:
# [NbConvertApp] Converting notebook FullyConnectedNets.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 4 image(s).
# [NbConvertApp] Writing 1099453 bytes to FullyConnectedNets.html

# %%
# !jupyter nbconvert --to html BatchNormalization.ipynb
# Out:
# [NbConvertApp] Converting notebook BatchNormalization.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 5 image(s).
# [NbConvertApp] Writing 1065371 bytes to BatchNormalization.html

# %%
# !jupyter nbconvert --to html Dropout.ipynb
# Out:
# [NbConvertApp] Converting notebook Dropout.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 390940 bytes to Dropout.html

# %%
# !jupyter nbconvert --to html ConvolutionalNetworks.ipynb
# Out:
# [NbConvertApp] Converting notebook ConvolutionalNetworks.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 4 image(s).
# [NbConvertApp] Writing 980024 bytes to ConvolutionalNetworks.html

# %%
# !jupyter nbconvert --to html PyTorch.ipynb
# Out:
# [NbConvertApp] Converting notebook PyTorch.ipynb to html
# [NbConvertApp] Writing 430220 bytes to PyTorch.html

# %%
from PyPDF2 import PdfMerger

pdfs = [
    "FullyConnectedNets.pdf",
    "BatchNormalization.pdf",
    "Dropout.pdf",
    "ConvolutionalNetworks.pdf",
    "PyTorch.pdf"
]
merger = PdfMerger()
for pdf in pdfs:
  merger.append(pdf)

merger.write("a2_inline_sumbission.pdf")
merger.close()
